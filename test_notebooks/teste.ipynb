# %%
import dash
from dash import dcc, dash_table
from dash import html
from dash.dependencies import Input, Output
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import plotly.express as px
import dash_bootstrap_components as dbc
import yfinance as yf
from datetime import datetime, timedelta
import talib as tb

# %%
date.today() - timedelta(days=1)
# Out:
# datetime.date(2022, 5, 23)

# %%
from datetime import date, timedelta
today = date.today()
yesterday = today - timedelta(days = 1)
print(today)
print(yesterday)
# Out:
# 2022-05-24
# 2022-05-23

# %%
df_coin = yf.download('SOL-USD', 
                      end=date.today(), 
                      progress=False,
    )

# %%
df_coin
# Out:
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 2020-04-10   0.832005   1.313487   0.694187   0.951054   0.951054    87364276
# 2020-04-11   0.951054   1.049073   0.765020   0.776819   0.776819    43862444
# 2020-04-12   0.785448   0.956670   0.762426   0.882507   0.882507    38736897
# 2020-04-13   0.890760   0.891603   0.773976   0.777832   0.777832    18211285
# 2020-04-14   0.777832   0.796472   0.628169   0.661925   0.661925    16747614
# ...               ...        ...        ...        ...        ...         ...
# 2022-05-19  49.794865  53.617489  48.635551  52.213978  52.213978  1958004386
# 2022-05-20  52.211971  53.438042  48.050583  49.538509  49.538509  1830699507
# 2022-05-21  49.535450  51.055050  48.767487  50.317982  50.317982   979492374
# 2022-05-22  50.320660  53.021660  49.862785  52.755180  52.755180  1105760506
# 2022-05-23  52.736088  54.474648  48.927246  49.056850  49.056850  1661669360
#
# [774 rows x 6 columns]

# %%
from get_all_tickers import get_tickers as gt

list_of_tickers = gt.get_tickers()
# or if you want to save them to a CSV file
get.save_tickers()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Users/rodrigopimenta/Documents/GitHub/BC5/teste.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/rodrigopimenta/Documents/GitHub/BC5/teste.ipynb#ch0000006?line=0'>1</a> from get_all_tickers import get_tickers as gt
# ----> <a href='vscode-notebook-cell:/Users/rodrigopimenta/Documents/GitHub/BC5/teste.ipynb#ch0000006?line=2'>3</a> list_of_tickers = gt.get_tickers()
#       <a href='vscode-notebook-cell:/Users/rodrigopimenta/Documents/GitHub/BC5/teste.ipynb#ch0000006?line=3'>4</a> # or if you want to save them to a CSV file
#       <a href='vscode-notebook-cell:/Users/rodrigopimenta/Documents/GitHub/BC5/teste.ipynb#ch0000006?line=4'>5</a> get.save_tickers()
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py:73, in get_tickers(NYSE, NASDAQ, AMEX)
#      <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=70'>71</a> tickers_list = []
#      <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=71'>72</a> if NYSE:
# ---> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=72'>73</a>     tickers_list.extend(__exchange2list('nyse'))
#      <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=73'>74</a> if NASDAQ:
#      <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=74'>75</a>     tickers_list.extend(__exchange2list('nasdaq'))
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py:138, in __exchange2list(exchange)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=136'>137</a> def __exchange2list(exchange):
# --> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=137'>138</a>     df = __exchange2df(exchange)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=138'>139</a>     # removes weird tickers
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=139'>140</a>     df_filtered = df[~df['Symbol'].str.contains("\.|\^")]
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py:134, in __exchange2df(exchange)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=131'>132</a> response = requests.get('https://old.nasdaq.com/screening/companies-by-name.aspx', headers=headers, params=params(exchange))
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=132'>133</a> data = io.StringIO(response.text)
# --> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=133'>134</a> df = pd.read_csv(data, sep=",")
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/get_all_tickers/get_tickers.py?line=134'>135</a> return df
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=579'>580</a> with parser:
# --> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=580'>581</a>     return parser.read(nrows)
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1251'>1252</a> nrows = validate_integer("nrows", nrows)
#    <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1252'>1253</a> try:
# -> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1253'>1254</a>     index, columns, col_dict = self._engine.read(nrows)
#    <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1254'>1255</a> except Exception:
#    <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1255'>1256</a>     self.close()
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=222'>223</a> try:
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=223'>224</a>     if self.low_memory:
# --> <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=224'>225</a>         chunks = self._reader.read_low_memory(nrows)
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=225'>226</a>         # destructive to chunks
#     <a href='file:///Users/rodrigopimenta/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=226'>227</a>         data = _concatenate_chunks(chunks)
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/opt/anaconda3/envs/BC/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 6, saw 47

# %%
import requests

url = 'https://web-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

for start in range(1, 20000, 5000):

    params = {
        'start': start,
        'limit': 5000,
    }

    r = requests.get(url, params=params)
    data = r.json()
    list_crypto =[]
    for number, item in enumerate(data['data']):
       list_crypto.append("{item['symbol']:5}")

# %%
import requests

url = 'https://web-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

for start in range(1, 20000, 5000):

    params = {
        'start': start,
        'limit': 5000,
    }

# %%
r = requests.get(url, params=params)
data = r.json()

# %%
data
# Out:
# {'status': {'timestamp': '2022-05-24T12:22:58.869Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 15,
#   'credit_count': 0,
#   'notice': None,
#   'total_count': 10048},
#  'data': []}

# %%
for number, item in enumerate(data['data']):
        print(f"{start+number:4} | {item['symbol']:5} | {item['date_added'][:10]}")

# %%
import requests

url = 'https://web-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
list_crypto=[]
for start in range(1, 20000, 5000):

    params = {
        'start': start,
        'limit': 5000,
    }

    r = requests.get(url, params=params)
    data = r.json()
    for number, item in enumerate(data['data']):
        a = f"{item['symbol']}-USD"
        list_crypto.append(a)

# %%
list_crypto
# Out:
# ['BTC-USD',
#  'ETH-USD',
#  'USDT-USD',
#  'USDC-USD',
#  'BNB-USD',
#  'XRP-USD',
#  'BUSD-USD',
#  'ADA-USD',
#  'SOL-USD',
#  'DOGE-USD',
#  'DOT-USD',
#  'WBTC-USD',
#  'AVAX-USD',
#  'TRX-USD',
#  'DAI-USD',
#  'SHIB-USD',
#  'MATIC-USD',
#  'LTC-USD',
#  'CRO-USD',
#  'LEO-USD',
#  'UNI-USD',
#  'NEAR-USD',
#  'FTT-USD',
#  'BCH-USD',
#  'XMR-USD',
#  'LINK-USD',
#  'XLM-USD',
#  'ATOM-USD',
#  'ETC-USD',
#  'FLOW-USD',
#  'ALGO-USD',
#  'APE-USD',
#  'HBAR-USD',
#  'VET-USD',
#  'EGLD-USD',
#  'MANA-USD',
#  'XTZ-USD',
#  'ICP-USD',
#  'FIL-USD',
#  'KCS-USD',
#  'SAND-USD',
#  'ZEC-USD',
#  'AAVE-USD',
#  'EOS-USD',
#  'KLAY-USD',
#  'MKR-USD',
#  'AXS-USD',
#  'THETA-USD',
#  'TUSD-USD',
#  'HT-USD',
#  'FTM-USD',
#  'GRT-USD',
#  'BTT-USD',
#  'RUNE-USD',
#  'BSV-USD',
#  'XEC-USD',
#  'USDP-USD',
#  'HNT-USD',
#  'MIOTA-USD',
#  'CAKE-USD',
#  'USDN-USD',
#  'QNT-USD',
#  'GMT-USD',
#  'NEO-USD',
#  'OKB-USD',
#  'STX-USD',
#  'UST-USD',
#  'LRC-USD',
#  'NEXO-USD',
#  'CHZ-USD',
#  'KSM-USD',
#  'ZIL-USD',
#  'DASH-USD',
#  'CVX-USD',
#  'PAXG-USD',
#  'WAVES-USD',
#  'ENJ-USD',
#  'BAT-USD',
#  'CELO-USD',
#  'CRV-USD',
#  'GALA-USD',
#  'ONE-USD',
#  'AMP-USD',
#  'GNO-USD',
#  'USDD-USD',
#  'MINA-USD',
#  'DCR-USD',
#  'XDC-USD',
#  'KAVA-USD',
#  'XEM-USD',
#  'COMP-USD',
#  'AR-USD',
#  'BTG-USD',
#  'KDA-USD',
#  'HOT-USD',
#  'GT-USD',
#  'FEI-USD',
#  '1INCH-USD',
#  'QTUM-USD',
#  'IOTX-USD',
#  'KNC-USD',
#  'ZRX-USD',
#  'LDO-USD',
#  'OMG-USD',
#  'ICX-USD',
#  'XYM-USD',
#  'LPT-USD',
#  'BORA-USD',
#  'BNT-USD',
#  'TFUEL-USD',
#  'YFI-USD',
#  'ROSE-USD',
#  'GLMR-USD',
#  'SCRT-USD',
#  'AUDIO-USD',
#  'ANKR-USD',
#  'IOST-USD',
#  'JST-USD',
#  'CHSB-USD',
#  'RVN-USD',
#  'SNX-USD',
#  'SRM-USD',
#  'SKL-USD',
#  'SC-USD',
#  'ELON-USD',
#  'WAXP-USD',
#  'GUSD-USD',
#  'GLM-USD',
#  'ZEN-USD',
#  'ONT-USD',
#  'SXP-USD',
#  'ENS-USD',
#  'IMX-USD',
#  'BTRST-USD',
#  'UMA-USD',
#  'NFT-USD',
#  'RNDR-USD',
#  'VGX-USD',
#  'STORJ-USD',
#  'MXC-USD',
#  'POLY-USD',
#  'WOO-USD',
#  'SUSHI-USD',
#  'HIVE-USD',
#  'RENBTC-USD',
#  'PLA-USD',
#  'ILV-USD',
#  'TWT-USD',
#  'CSPR-USD',
#  'DGB-USD',
#  'RLY-USD',
#  'CEL-USD',
#  'KEEP-USD',
#  'FLUX-USD',
#  'CFX-USD',
#  'CKB-USD',
#  'LSK-USD',
#  'WIN-USD',
#  'VLX-USD',
#  'MX-USD',
#  'MED-USD',
#  'ACA-USD',
#  'XNO-USD',
#  'XPRT-USD',
#  'REN-USD',
#  'TEL-USD',
#  'XCH-USD',
#  'CEEK-USD',
#  'EPS-USD',
#  'OCEAN-USD',
#  'ORBS-USD',
#  'DYDX-USD',
#  'DAG-USD',
#  'ANC-USD',
#  'PEOPLE-USD',
#  'XDB-USD',
#  'REQ-USD',
#  'SYS-USD',
#  'PUNDIX-USD',
#  'CELR-USD',
#  'SPELL-USD',
#  'XYO-USD',
#  'INJ-USD',
#  'POWR-USD',
#  'DAO-USD',
#  'COTI-USD',
#  'NU-USD',
#  'CHR-USD',
#  'ONG-USD',
#  'FET-USD',
#  'SNT-USD',
#  'REP-USD',
#  'C98-USD',
#  'CVC-USD',
#  'TRIBE-USD',
#  'WXT-USD',
#  'MDX-USD',
#  'FXS-USD',
#  'UOS-USD',
#  'TRAC-USD',
#  'HEX-USD',
#  'WTRX-USD',
#  'stETH-USD',
#  'YOUC-USD',
#  'BTCB-USD',
#  'WBNB-USD',
#  'TON-USD',
#  'XCN-USD',
#  'FRAX-USD',
#  'BTTOLD-USD',
#  'DFI-USD',
#  'HBTC-USD',
#  'LUNA-USD',
#  'LUSD-USD',
#  'SAFE-USD',
#  'OSMO-USD',
#  'BIT-USD',
#  'XAUT-USD',
#  'NXM-USD',
#  'SAPP-USD',
#  'WEMIX-USD',
#  'HUSD-USD',
#  'T-USD',
#  'TTT-USD',
#  'CCXX-USD',
#  'LN-USD',
#  'FRTS-USD',
#  'EVER-USD',
#  'BNX-USD',
#  'LOOKS-USD',
#  'BEST-USD',
#  'GAL-USD',
#  'RPL-USD',
#  'ASTR-USD',
#  'XWC-USD',
#  'RACA-USD',
#  'HUM-USD',
#  'KOK-USD',
#  'VVS-USD',
#  'WVLX-USD',
#  'GST-USD',
#  'MVL-USD',
#  'TITAN-USD',
#  'MOB-USD',
#  'CBG-USD',
#  'BSW-USD',
#  'EURS-USD',
#  'DESO-USD',
#  'ARRR-USD',
#  'AVINOC-USD',
#  'CTC-USD',
#  'AURORA-USD',
#  'SURE-USD',
#  'SOLO-USD',
#  'ARDR-USD',
#  'METIS-USD',
#  'ANY-USD',
#  'PERP-USD',
#  'DENT-USD',
#  'PYR-USD',
#  'ACH-USD',
#  'RAY-USD',
#  'XSGD-USD',
#  '1ECO-USD',
#  'HXRO-USD',
#  'USDX-USD',
#  'LOCUS-USD',
#  'FX-USD',
#  'HYN-USD',
#  'JOE-USD',
#  'STEEM-USD',
#  'DIVI-USD',
#  'vUSDC-USD',
#  'LQTY-USD',
#  'MPL-USD',
#  'CTSI-USD',
#  'ASD-USD',
#  'DAR-USD',
#  'FUN-USD',
#  'NEST-USD',
#  'MOVR-USD',
#  'PLTC-USD',
#  'REV-USD',
#  'WRX-USD',
#  'SUN-USD',
#  'HEDG-USD',
#  'STMX-USD',
#  'TLM-USD',
#  'BTCST-USD',
#  'SUSD-USD',
#  'MTL-USD',
#  'RBTC-USD',
#  'OGN-USD',
#  'OXT-USD',
#  'VTHO-USD',
#  'RSR-USD',
#  'TLOS-USD',
#  'ALICE-USD',
#  'BICO-USD',
#  'SUPER-USD',
#  'BLOK-USD',
#  'RKN-USD',
#  'XCAD-USD',
#  'RGT-USD',
#  'XVG-USD',
#  'ELF-USD',
#  'STRK-USD',
#  'EWT-USD',
#  'HERO-USD',
#  'META-USD',
#  'REEF-USD',
#  'ABBC-USD',
#  'UQC-USD',
#  'HOO-USD',
#  'LYXe-USD',
#  'MV-USD',
#  'GHST-USD',
#  'DEP-USD',
#  'SNL-USD',
#  'YGG-USD',
#  'SSV-USD',
#  'STRAX-USD',
#  'ANT-USD',
#  'ORC-USD',
#  'BFC-USD',
#  'MBOX-USD',
#  'DAWN-USD',
#  'ALPHA-USD',
#  'UTK-USD',
#  'MAID-USD',
#  'BOBA-USD',
#  'NMR-USD',
#  'SSX-USD',
#  'ADS-USD',
#  'PROM-USD',
#  'PRO-USD',
#  'ZEON-USD',
#  'QKC-USD',
#  'BETA-USD',
#  'RIF-USD',
#  'ERG-USD',
#  'BADGER-USD',
#  'NRG-USD',
#  'MBL-USD',
#  'STPT-USD',
#  'ARK-USD',
#  'SPS-USD',
#  'RLC-USD',
#  'DERO-USD',
#  'MCT-USD',
#  'KLV-USD',
#  'CRTS-USD',
#  'BRG-USD',
#  'CENNZ-USD',
#  'EXRD-USD',
#  'UFO-USD',
#  'NKN-USD',
#  'VERI-USD',
#  'AGIX-USD',
#  'LOOM-USD',
#  'SAFEMOON-USD',
#  'ZB-USD',
#  'API3-USD',
#  'OUSD-USD',
#  'MNGO-USD',
#  'GTN-USD',
#  'RAD-USD',
#  'CFG-USD',
#  'MLN-USD',
#  'CUSD-USD',
#  'CORE-USD',
#  'AMPL-USD',
#  'BAND-USD',
#  'JASMY-USD',
#  'IQ-USD',
#  'POLS-USD',
#  'DVI-USD',
#  'WMT-USD',
#  'vBUSD-USD',
#  'STAKE-USD',
#  'ETN-USD',
#  'FWT-USD',
#  'ONUS-USD',
#  'XVS-USD',
#  'NSBT-USD',
#  'CTK-USD',
#  'KAI-USD',
#  'IDEX-USD',
#  'DKA-USD',
#  'FOX-USD',
#  'TT-USD',
#  'PRE-USD',
#  'DPI-USD',
#  'MASK-USD',
#  'BAKE-USD',
#  'XPR-USD',
#  'DUSK-USD',
#  'WOZX-USD',
#  'DMCH-USD',
#  'SPA-USD',
#  'aETHc-USD',
#  'VAI-USD',
#  'ORN-USD',
#  'EGG-USD',
#  'HUNT-USD',
#  'QC-USD',
#  'ALEPH-USD',
#  'YOOSHI-USD',
#  'TRU-USD',
#  'BAL-USD',
#  'AERGO-USD',
#  'AKT-USD',
#  'TOMO-USD',
#  'FORTH-USD',
#  'AIOZ-USD',
#  'DPR-USD',
#  'DVF-USD',
#  'COCOS-USD',
#  'MFT-USD',
#  'BNANA-USD',
#  'BIFI-USD',
#  'CRE-USD',
#  'VRSC-USD',
#  'LCX-USD',
#  'ALPACA-USD',
#  'CON-USD',
#  'UBT-USD',
#  'GENE-USD',
#  'YFII-USD',
#  'MC-USD',
#  'SFP-USD',
#  'TKO-USD',
#  'ALT-USD',
#  'SOS-USD',
#  'STARL-USD',
#  'AXEL-USD',
#  'LAT-USD',
#  'HTR-USD',
#  'RMRK-USD',
#  'ALCX-USD',
#  'FLETA-USD',
#  'POND-USD',
#  'GMT-USD',
#  'WAN-USD',
#  'ARPA-USD',
#  'NCT-USD',
#  'XNC-USD',
#  'SFUND-USD',
#  'erowan-USD',
#  'MONA-USD',
#  'VOXEL-USD',
#  'VR-USD',
#  'BCD-USD',
#  'AQT-USD',
#  'MUSD-USD',
#  'AGLD-USD',
#  'GXC-USD',
#  'MWC-USD',
#  'NOIA-USD',
#  'ALPINE-USD',
#  'CQT-USD',
#  'BOO-USD',
#  'SOV-USD',
#  'HI-USD',
#  'ELA-USD',
#  'CLV-USD',
#  'LTO-USD',
#  'KILT-USD',
#  'MOC-USD',
#  'VXV-USD',
#  'EUM-USD',
#  'RFR-USD',
#  'LON-USD',
#  'SWAP-USD',
#  'RISE-USD',
#  'MLK-USD',
#  'LINA-USD',
#  'QRDO-USD',
#  'TROY-USD',
#  'HNS-USD',
#  'VELO-USD',
#  'GTC-USD',
#  'TORN-USD',
#  'BTS-USD',
#  'AVA-USD',
#  'CLT-USD',
#  'SERO-USD',
#  'SOUL-USD',
#  'DG-USD',
#  'UPP-USD',
#  'ALI-USD',
#  'MIR-USD',
#  'DIA-USD',
#  'CBK-USD',
#  'PHA-USD',
#  'HYDRA-USD',
#  'AURY-USD',
#  'VRA-USD',
#  'FARM-USD',
#  'QOM-USD',
#  'PEAK-USD',
#  'COVAL-USD',
#  'EFI-USD',
#  'ATOLO-USD',
#  'GRS-USD',
#  'SWP-USD',
#  'TPT-USD',
#  'ADX-USD',
#  'DDX-USD',
#  'RAI-USD',
#  'IRIS-USD',
#  'vUSDT-USD',
#  'ATA-USD',
#  'ULT-USD',
#  'LOKA-USD',
#  'DNT-USD',
#  'COS-USD',
#  'LA-USD',
#  'CTCN-USD',
#  'FLM-USD',
#  'KMD-USD',
#  'WNXM-USD',
#  'WILD-USD',
#  'SDAO-USD',
#  'QUACK-USD',
#  'BOSON-USD',
#  'SLP-USD',
#  'ZLW-USD',
#  'CET-USD',
#  'TVK-USD',
#  'SIX-USD',
#  'BABY-USD',
#  'ASM-USD',
#  'ERN-USD',
#  'HARD-USD',
#  'DAD-USD',
#  'BZRX-USD',
#  'VEGA-USD',
#  'BTSE-USD',
#  'BIOT-USD',
#  'CUDOS-USD',
#  'APX-USD',
#  'KP3R-USD',
#  'NYE-USD',
#  'RSV-USD',
#  'SBD-USD',
#  'USDK-USD',
#  'XHV-USD',
#  'BOR-USD',
#  'YLD-USD',
#  'ZASH-USD',
#  'AE-USD',
#  'DXD-USD',
#  'BSCPAD-USD',
#  'BMX-USD',
#  'MOF-USD',
#  'ROOK-USD',
#  'NIF-USD',
#  'DREP-USD',
#  'GAS-USD',
#  'MIX-USD',
#  'DATA-USD',
#  'MSOL-USD',
#  'H2O-USD',
#  'CTXC-USD',
#  'FIO-USD',
#  'HIGH-USD',
#  'QSP-USD',
#  'LOG-USD',
#  'DGD-USD',
#  'RARI-USD',
#  'RARE-USD',
#  'PNK-USD',
#  'MARO-USD',
#  'OXEN-USD',
#  'BZZ-USD',
#  'FIDA-USD',
#  'RBN-USD',
#  'BLCT-USD',
#  'MNW-USD',
#  'RFOX-USD',
#  'MDT-USD',
#  'QUICK-USD',
#  'CHESS-USD',
#  'OM-USD',
#  'BOND-USD',
#  'AMO-USD',
#  'FCT,FCT2-USD',
#  'PSG-USD',
#  'BLZ-USD',
#  'CUBE-USD',
#  'FRONT-USD',
#  'LIT-USD',
#  'MAP-USD',
#  'NFTX-USD',
#  'REV-USD',
#  'DERC-USD',
#  'KIN-USD',
#  'FIRO-USD',
#  'CIV-USD',
#  'NULS-USD',
#  'HOPR-USD',
#  'TIME-USD',
#  'WNCG-USD',
#  'PRQ-USD',
#  'MET-USD',
#  'AHT-USD',
#  'RVP-USD',
#  'ALBT-USD',
#  'CXO-USD',
#  'STC-USD',
#  'GRID-USD',
#  'PNY-USD',
#  'TABOO-USD',
#  'GYEN-USD',
#  'LAZIO-USD',
#  'AKRO-USD',
#  'vXVS-USD',
#  'SOFI-USD',
#  'POSI-USD',
#  'VBIT-USD',
#  'FSN-USD',
#  'HEZ-USD',
#  'SANTOS-USD',
#  'SDN-USD',
#  'GOM2-USD',
#  'TNC-USD',
#  'NMC-USD',
#  'GF-USD',
#  'KEY-USD',
#  'ZNN-USD',
#  'MEV-USD',
#  'KRL-USD',
#  'WHALE-USD',
#  'DOCK-USD',
#  'OOKI-USD',
#  'RAMP-USD',
#  'REAP-USD',
#  'IHF-USD',
#  'CITY-USD',
#  'DX-USD',
#  'SAMO-USD',
#  'LTX-USD',
#  'BF-USD',
#  'MAPS-USD',
#  'BUX-USD',
#  'MOBI-USD',
#  'ATLAS-USD',
#  'DEXE-USD',
#  'THG-USD',
#  'DODO-USD',
#  'QASH-USD',
#  'FIS-USD',
#  'CRPT-USD',
#  'SAITO-USD',
#  'PORTO-USD',
#  'BANANA-USD',
#  'NGM-USD',
#  'ADP-USD',
#  'BTM-USD',
#  'MVC-USD',
#  'MITH-USD',
#  'XDEFI-USD',
#  'ARV-USD',
#  'BEL-USD',
#  'SOLVE-USD',
#  'SHPING-USD',
#  'ERA-USD',
#  'XWG-USD',
#  'AION-USD',
#  'KAR-USD',
#  'URUS-USD',
#  'EDG-USD',
#  'CREAM-USD',
#  'BEAM-USD',
#  'IDIA-USD',
#  'GXT-USD',
#  'DEXT-USD',
#  'BAR-USD',
#  'BTR-USD',
#  'QTCON-USD',
#  'TRB-USD',
#  'GET-USD',
#  'XMON-USD',
#  'DF-USD',
#  'BOA-USD',
#  'GODS-USD',
#  'WICC-USD',
#  'SCP-USD',
#  'TNB-USD',
#  'ASK-USD',
#  'PCX-USD',
#  'RSS3-USD',
#  'MATH-USD',
#  'NWC-USD',
#  'ICHI-USD',
#  'HDAO-USD',
#  'CERE-USD',
#  'APL-USD',
#  'BASIC-USD',
#  'BIDR-USD',
#  'WTC-USD',
#  'SAN-USD',
#  'ONIT-USD',
#  'POA-USD',
#  'TMTG-USD',
#  'GAFI-USD',
#  'PLU-USD',
#  'USDJ-USD',
#  'GTO-USD',
#  'BCN-USD',
#  'IDRT-USD',
#  'EPIC-USD',
#  'AOG-USD',
#  'PDEX-USD',
#  'INSUR-USD',
#  'SUKU-USD',
#  'VEED-USD',
#  'STACK-USD',
#  'ROUTE-USD',
#  'NIM-USD',
#  'QRL-USD',
#  'CTX-USD',
#  'GO-USD',
#  'POLIS-USD',
#  'EVZ-USD',
#  'CVP-USD',
#  'SLIM-USD',
#  'AUCTION-USD',
#  'KDAG-USD',
#  'GFI-USD',
#  'BURGER-USD',
#  'XCP-USD',
#  'KAN-USD',
#  'NUM-USD',
#  'EL-USD',
#  'VITE-USD',
#  'ID-USD',
#  'LNR-USD',
#  'ERC20-USD',
#  'SLND-USD',
#  'AST-USD',
#  'PNT-USD',
#  'GRIN-USD',
#  'DFA-USD',
#  'FOR-USD',
#  'WOOP-USD',
#  'PZM-USD',
#  'ALU-USD',
#  'OLT-USD',
#  'BTU-USD',
#  'BEPRO-USD',
#  'NBS-USD',
#  'MTA-USD',
#  'XOR-USD',
#  'RAINI-USD',
#  'CAPS-USD',
#  'TEMCO-USD',
#  'PEX-USD',
#  'VSYS-USD',
#  'TOWN-USD',
#  'ACM-USD',
#  'ZBC-USD',
#  'DORA-USD',
#  'DG-USD',
#  'DVPN-USD',
#  'DEGO-USD',
#  'PAC-USD',
#  'BIR-USD',
#  'ARIA20-USD',
#  'CLO-USD',
#  'PKT-USD',
#  'ZKS-USD',
#  'SHIRYO-USD',
#  'HAI-USD',
#  'DOV-USD',
#  'GHX-USD',
#  'FLX-USD',
#  'CELL-USD',
#  'NXS-USD',
#  'SHX-USD',
#  'SWTH-USD',
#  'SOC-USD',
#  'GBYTE-USD',
#  'VTC-USD',
#  'CRA-USD',
#  'BAN-USD',
#  'HIBS-USD',
#  'ANCT-USD',
#  'VSP-USD',
#  'UNCX-USD',
#  'HOGE-USD',
#  'MEETONE-USD',
#  'VISR-USD',
#  'O3-USD',
#  'RDD-USD',
#  'OBSR-USD',
#  'PALLA-USD',
#  'XNO-USD',
#  'LBC-USD',
#  'NEX-USD',
#  'UNFI-USD',
#  'LBL-USD',
#  'STOS-USD',
#  'CHP-USD',
#  'BTC2-USD',
#  'GLCH-USD',
#  'PPC-USD',
#  'WING-USD',
#  'VIDT-USD',
#  'HPT-USD',
#  'ZIG-USD',
#  'ZCN-USD',
#  'VID-USD',
#  'BIP-USD',
#  'TOC-USD',
#  'XEP-USD',
#  'GAL-USD',
#  'MOBIC-USD',
#  'INV-USD',
#  'LGCY-USD',
#  'CGG-USD',
#  'PERL-USD',
#  'ABT-USD',
#  'LSS-USD',
#  'AUTO-USD',
#  'DOGEDASH-USD',
#  'TCT-USD',
#  'WIKEN-USD',
#  'RBC-USD',
#  'OPUL-USD',
#  'VRT-USD',
#  'SOCKS-USD',
#  'PIVX-USD',
#  'INTER-USD',
#  'NFTY-USD',
#  'PROB-USD',
#  'SHFT-USD',
#  'ES-USD',
#  'FOAM-USD',
#  'SHR-USD',
#  'REVV-USD',
#  'RAE-USD',
#  'BLP-USD',
#  'FUSE-USD',
#  'HOTCROSS-USD',
#  'LOTTO-USD',
#  'VAL-USD',
#  'QQQ-USD',
#  'CYCLUB-USD',
#  'PUSH-USD',
#  'STARS-USD',
#  'AGRS-USD',
#  'PENDLE-USD',
#  'EPIK-USD',
#  'UPUNK-USD',
#  'PORNROCKET-USD',
#  'PKF-USD',
#  'BTRS-USD',
#  'METAG-USD',
#  'DRGN-USD',
#  'DACXI-USD',
#  'GMM-USD',
#  'MATTER-USD',
#  'ONE-USD',
#  'TREEB-USD',
#  'KYL-USD',
#  'NFTD-USD',
#  'PLANETS-USD',
#  'NEW-USD',
#  'UFT-USD',
#  'ORAI-USD',
#  'MINT-USD',
#  'HC-USD',
#  'GPX-USD',
#  'AVT-USD',
#  'UPI-USD',
#  'APM-USD',
#  'BRWL-USD',
#  'TEN-USD',
#  'SIGNA-USD',
#  'STAX-USD',
#  'GMCOIN-USD',
#  'PNG-USD',
#  'XPX-USD',
#  'PPT-USD',
#  'RDN-USD',
#  'SPIRIT-USD',
#  'ZANO-USD',
#  'MOOV-USD',
#  'BELT-USD',
#  'MHC-USD',
#  'ROOBEE-USD',
#  'DFL-USD',
#  'SLRS-USD',
#  'MBN-USD',
#  'ATM-USD',
#  'IFC-USD',
#  'ATRI-USD',
#  'DSLA-USD',
#  'NEWS-USD',
#  'POLK-USD',
#  'SHILL-USD',
#  'CWV-USD',
#  'BTCP-USD',
#  'PART-USD',
#  'ACE-USD',
#  'VEMP-USD',
#  'GOC-USD',
#  'STANDARD-USD',
#  'BRD-USD',
#  'AAB-USD',
#  'ZYN-USD',
#  'SFI-USD',
#  'TRV-USD',
#  'XED-USD',
#  'EMRX-USD',
#  'STRX-USD',
#  'SNTVT-USD',
#  'BAX-USD',
#  'SCC-USD',
#  'OOE-USD',
#  'SYLO-USD',
#  'POOLZ-USD',
#  'IGNIS-USD',
#  'ASTA-USD',
#  'NAV-USD',
#  'VEE-USD',
#  'BTNT-USD',
#  'TON-USD',
#  'PAID-USD',
#  'PMON-USD',
#  'K21-USD',
#  'vDAI-USD',
#  'NOW-USD',
#  'vLTC-USD',
#  'AWC-USD',
#  'NAS-USD',
#  'KUNCI-USD',
#  'MSB-USD',
#  'MLT-USD',
#  'MCB-USD',
#  'WOM-USD',
#  'SAFE-USD',
#  'GOVI-USD',
#  'ILC-USD',
#  'TONE-USD',
#  'UBX-USD',
#  'SPARTA-USD',
#  'HAPI-USD',
#  'TRA-USD',
#  'THN-USD',
#  'NFTART-USD',
#  'CGT-USD',
#  'JUP-USD',
#  'BFT-USD',
#  'MITX-USD',
#  'XFT-USD',
#  'VALOR-USD',
#  'ASR-USD',
#  'BAAS-USD',
#  'GTON-USD',
#  'SEELE-USD',
#  'PRIMATE-USD',
#  'TFT-USD',
#  'HAM-USD',
#  'JULD-USD',
#  'HEGIC-USD',
#  'IPAD-USD',
#  'ABYSS-USD',
#  'CHI-USD',
#  'DAPS-USD',
#  'LEVL-USD',
#  'PI-USD',
#  'GEEQ-USD',
#  'SFT-USD',
#  'DMD-USD',
#  'GSWAP-USD',
#  'DIP-USD',
#  'BCMC-USD',
#  'DCN-USD',
#  'IQN-USD',
#  'BETU-USD',
#  'TRIX-USD',
#  'CHNG-USD',
#  'MTV-USD',
#  'SWASH-USD',
#  'FO-USD',
#  'DERI-USD',
#  'CAS-USD',
#  'GATE-USD',
#  'BLY-USD',
#  'DTEP-USD',
#  'VIDYA-USD',
#  'BHP-USD',
#  'ZOO-USD',
#  'SIN-USD',
#  'GAME-USD',
#  'KARMA-USD',
#  'INXT-USD',
#  ...]

# %%
import pandas as pd 
import numpy as np 
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit

# Models
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

import math

import datetime
from datetime import datetime as dt
from dateutil.relativedelta import *
from datetime import timedelta

# %%
import pandas as pd
import datetime
from datetime import datetime as dt
from dateutil.relativedelta import *

# code from: https://towardsdatascience.com/time-based-cross-validation-d259b13d42b8"

class TimeBasedCV(object):
    '''
    Parameters 
    ----------
    train_period: int
        number of time units to include in each train set
        default is 30
    test_period: int
        number of time units to include in each test set
        default is 7
    freq: string
        frequency of input parameters. possible values are: days, months, years, weeks, hours, minutes, seconds
        possible values designed to be used by dateutil.relativedelta class
        deafault is days
    '''
    
    
    def __init__(self, train_period=30, test_period=7, freq='days'):
        self.train_period = train_period
        self.test_period = test_period
        self.freq = freq

        
        
    def split(self, data, validation_split_date=None, date_column='record_date', gap=0):
        '''
        Generate indices to split data into training and test set
        
        Parameters 
        ----------
        data: pandas DataFrame
            your data, contain one column for the record date 
        validation_split_date: datetime.date()
            first date to perform the splitting on.
            if not provided will set to be the minimum date in the data after the first training set
        date_column: string, deafult='record_date'
            date of each record
        gap: int, default=0
            for cases the test set does not come right after the train set,
            *gap* days are left between train and test sets
        
        Returns 
        -------
        train_index ,test_index: 
            list of tuples (train index, test index) similar to sklearn model selection
        '''
        
        # check that date_column exist in the data:
        try:
            data[date_column]
        except:
            raise KeyError(date_column)
                    
        train_indices_list = []
        test_indices_list = []

        if validation_split_date==None:
            validation_split_date = data[date_column].min().date() + eval('relativedelta('+self.freq+'=self.train_period)')
        
        start_train = validation_split_date - eval('relativedelta('+self.freq+'=self.train_period)')
        end_train = start_train + eval('relativedelta('+self.freq+'=self.train_period)')
        start_test = end_train + eval('relativedelta('+self.freq+'=gap)')
        end_test = start_test + eval('relativedelta('+self.freq+'=self.test_period)')

        while end_test < data[date_column].max().date():
            # train indices:
            cur_train_indices = list(data[(data[date_column].dt.date>=start_train) & 
                                     (data[date_column].dt.date<end_train)].index)

            # test indices:
            cur_test_indices = list(data[(data[date_column].dt.date>=start_test) &
                                    (data[date_column].dt.date<end_test)].index)
            
            #print("Train period:",start_train,"-" , end_train, ", Test period", start_test, "-", end_test,
            #      "# train records", len(cur_train_indices), ", # test records", len(cur_test_indices))

            train_indices_list.append(cur_train_indices)
            test_indices_list.append(cur_test_indices)

            # update dates:
            start_train = start_train + eval('relativedelta('+self.freq+'=self.test_period)')
            end_train = start_train + eval('relativedelta('+self.freq+'=self.train_period)')
            start_test = end_train + eval('relativedelta('+self.freq+'=gap)')
            end_test = start_test + eval('relativedelta('+self.freq+'=self.test_period)')

        # mimic sklearn output  
        index_output = [(train,test) for train,test in zip(train_indices_list,test_indices_list)]

        self.n_splits = len(index_output)
        
        return index_output
    
    
    def get_n_splits(self):
        """Returns the number of splitting iterations in the cross-validator
        Returns
        -------
        n_splits : int
            Returns the number of splitting iterations in the cross-validator.
        """
        return self.n_splits

# %%
def add_days(df, forecast_length):
    end_point = len(df)
    df1 = pd.DataFrame(index=range(forecast_length), columns = ['Date','Close'])
    #df1.columns = ['Close', 'Date']
    df = df.append(df1)
    df = df.reset_index(drop=True)
    x = df.at[end_point - 1, 'Date']
    x = pd.to_datetime(x, format='%Y-%m-%d')
    for i in range(forecast_length):
        df.at[df.index[end_point + i], 'Date'] = x + timedelta(days=1+i)
        df.at[df.index[end_point + i], 'Close'] = 0
    df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
    df = df.drop(['Date'], axis=1)
    return df

# %%
def forecasting(model,df1, forecast_length):
    df3 = df1[['Close', 'Date']]
    df3 = add_days(df3, forecast_length)
    finaldf = df1.drop('Date', axis=1)
    finaldf = finaldf.reset_index(drop=True)
    end_point = len(finaldf)
    x = end_point - forecast_length
    finaldf_train = finaldf.loc[:x - 1, :]
    finaldf_train_x = finaldf_train.loc[:, finaldf_train.columns != 'Close']
    finaldf_train_y = finaldf_train['Close']

    fit = model.fit(finaldf_train_x, finaldf_train_y)
    yhat = []
    end_point = len(finaldf)
    df3_end = len(df3)
    for i in range(forecast_length, 0, -1):
        y = end_point - i
        inputfile = finaldf.loc[y:end_point, :]
        inputfile_x = inputfile.loc[:, inputfile.columns != 'Close']
        pred_set = inputfile_x.head(1)
        pred = fit.predict(pred_set)
        df3.at[df3.index[df3_end - i], 'Close'] = pred[0]
        finaldf = df1.drop('Date', axis=1)
        finaldf = finaldf.reset_index(drop=True)
        yhat.append(pred)
    yhat = np.array(yhat)
    return yhat

# %%
df_coin = yf.download('BTC-USD',
                      end=date.today() - timedelta(days=1), 
                      progress=False,
    )
def df_converter(df): 
    df_sp500 = yf.download('^GSPC', 
                      start='2017-11-09', 
                      end='2022-05-08', 
                      progress=False)
    df_dollar = yf.download('DX=F', 
                      start='2017-11-09', 
                      end='2022-05-08', 
                      progress=False)
    # clearing dollar and sp500 df
    df_dollar.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
    df_dollar.rename(columns={"Close": "dollar_close"}, inplace=True)
    df_sp500.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
    df_sp500.rename(columns={"Close": "sp500_close"}, inplace=True)
    # clearing general df
    #df_eth.drop('Unnamed: 0', axis=1, inplace=True)
    #df.drop('adj_close', axis=1, inplace=True)
    df.index = df.index.astype('datetime64[ns]')
    # MA df
    df_ma = df['Close'].to_frame()
    df_ma['SMA30'] = df_ma['Close'].rolling(15).mean()
    df_ma['CMA30'] = df_ma['Close'].expanding().mean()
    df_ma['EMA30'] = tb.EMA(df_ma['Close'], timeperiod=15)
    df_ma.dropna(inplace=True)
    # Stoch df
    slowk, slowd = tb.STOCH(df["High"], df["Low"], df["Close"], fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
    df_stoch = pd.DataFrame(index=df.index,
                                data={"slowk": slowk,
                                    "slowd": slowd})
    df_stoch.dropna(inplace=True)
    # for later use in the concat
    stoch_c = ['slowk', 'slowd']
    # MACD df 
    macd, macdsignal, macdhist = tb.MACD(df.Close, fastperiod=12, slowperiod=26, signalperiod=9)
    df_macd = pd.DataFrame(index=df.index,
                            data={"macd": macd,
                                  "macdsignal": macdsignal,
                                  "macdhist": macdhist})
    df_macd.dropna(inplace=True)
    # for later use in the concat
    macd_c = ['macd', 'macdsignal', 'macdhist']
    # bb df
    upper, middle, lower = tb.BBANDS(df["Close"], timeperiod=15)
    df_bands = pd.DataFrame(index=df.index,
                                data={"bb_low": lower,
                                    "bb_ma": middle,
                                    "bb_high": upper})
    df_bands.dropna(inplace=True)
    # for later use in the concat
    bands_c = ['bb_low', 'bb_ma', 'bb_high']
    # rsi df
    rsi = tb.RSI(df['Close'], timeperiod=15)
    df_rsi = pd.DataFrame(index=df.index,
                            data={"close": df['Close'],
                                  "rsi": rsi})

    df_rsi.dropna(inplace=True)
    #stdev df
    stdev = tb.STDDEV(df['Close'], timeperiod=15, nbdev=1)
    df_stdev = pd.DataFrame(index=df.index,
                            data={"close": df['Close'],
                                  "stdev": stdev})
    df_stdev.dropna(inplace=True)
    # adx df
    adx = tb.ADX(df['High'], df['Low'], df['Close'], timeperiod=15)
    df_adx = pd.DataFrame(index=df.index,
                                data={"close": df['Close'],
                                    "adx": adx})

    df_adx.dropna(inplace=True)

    # concat 
    result =pd.concat([df, df_ma[['SMA30','CMA30','EMA30']], df_adx['adx'], df_bands[bands_c], df_macd[macd_c], df_rsi['rsi'], df_stdev['stdev'], df_stoch[stoch_c], df_dollar['dollar_close'], df_sp500['sp500_close']], axis=1)
    result.fillna(method='ffill', inplace=True)
    result.dropna(inplace=True)

    return result 

df_coin = df_converter(df_coin)
df_coin
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-11-09   7446.830078   7446.830078   7101.520020   7143.580078
# 2017-11-10   7173.729980   7312.000000   6436.870117   6618.140137
# 2017-11-11   6618.609863   6873.149902   6204.220215   6357.600098
# 2017-11-12   6295.450195   6625.049805   5519.009766   5950.069824
# 2017-11-13   5938.250000   6811.189941   5844.290039   6559.490234
# ...                  ...           ...           ...           ...
# 2022-05-13  29030.910156  30924.802734  28782.330078  29283.103516
# 2022-05-14  29285.642578  30192.802734  28702.910156  30101.265625
# 2022-05-15  30098.585938  31308.191406  29527.740234  31305.113281
# 2022-05-16  31304.375000  31305.341797  29251.884766  29862.917969
# 2022-05-17  29862.408203  30694.490234  29570.302734  30425.857422
#
#                Adj Close       Volume         SMA30         CMA30  \
# Date
# 2017-11-09   7143.580078   3226249984   6720.195964   1012.489040
# 2017-11-10   6618.140137   5208249856   6767.749967   1017.359285
# 2017-11-11   6357.600098   4908680192   6806.196647   1021.994910
# 2017-11-12   5950.069824   8957349888   6819.328646   1026.269043
# 2017-11-13   6559.490234   6263249920   6846.371322   1031.063862
# ...                  ...          ...           ...           ...
# 2022-05-13  29283.103516  42841124537  34769.086458  12181.561138
# 2022-05-14  30101.265625  28579868620  34201.849219  12187.967897
# 2022-05-15  31305.113281  25835372065  33774.531771  12194.800329
# 2022-05-16  29862.917969  32613897286  33200.786719  12201.112625
# 2022-05-17  30425.857422  29101473475  32660.555339  12207.621463
#
#                    EMA30        adx  ...       bb_high         macd  \
# Date                                 ...
# 2017-11-09   6798.973215  37.428679  ...   7929.899976   547.298468
# 2017-11-10   6776.369081  36.238180  ...   7899.045668   482.149729
# 2017-11-11   6724.022958  34.548539  ...   7835.311479   404.828866
# 2017-11-12   6627.278816  32.896648  ...   7798.154128   307.126870
# 2017-11-13   6618.805243  30.978407  ...   7771.077715   275.694434
# ...                  ...        ...  ...           ...          ...
# 2022-05-13  33752.713117  37.727339  ...  42450.221952 -2960.551674
# 2022-05-14  33296.282181  39.149053  ...  41921.267552 -2966.248122
# 2022-05-15  33047.386068  39.613857  ...  41377.532033 -2840.874322
# 2022-05-16  32649.327556  40.123429  ...  40596.192649 -2825.319270
# 2022-05-17  32371.393789  40.599029  ...  39589.225018 -2736.028041
#
#              macdsignal    macdhist        rsi        stdev      slowk  \
# Date
# 2017-11-09   521.809901   25.488567  65.836431   604.852006  33.184032
# 2017-11-10   513.877867  -31.728137  55.203600   565.647850  30.022892
# 2017-11-11   492.068066  -87.239201  50.841315   514.557416  13.668599
# 2017-11-12   455.079827 -147.952957  44.895661   489.412741  14.127749
# 2017-11-13   419.202748 -143.508315  53.591318   462.353197  27.607649
# ...                 ...         ...        ...          ...        ...
# 2022-05-13 -2152.011629 -808.540044  26.956772  3840.567747  25.449680
# 2022-05-14 -2314.858928 -651.389194  30.683438  3859.709167  42.259552
# 2022-05-15 -2420.062007 -420.812316  35.843737  3801.500131  61.600258
# 2022-05-16 -2501.113459 -324.205811  32.717422  3697.702965  72.797664
# 2022-05-17 -2548.096376 -187.931666  35.085322  3464.334839  74.824425
#
#                 slowd  dollar_close  sp500_close
# Date
# 2017-11-09  38.772059     94.351997  2584.620117
# 2017-11-10  33.577955     94.278000  2582.300049
# 2017-11-11  25.625174     94.278000  2582.300049
# 2017-11-12  19.273080     94.278000  2582.300049
# 2017-11-13  18.467999     94.388000  2584.840088
# ...               ...           ...          ...
# 2022-05-13  17.482894    103.694000  4123.339844
# 2022-05-14  28.706821    103.694000  4123.339844
# 2022-05-15  43.103163    103.694000  4123.339844
# 2022-05-16  58.885824    103.694000  4123.339844
# 2022-05-17  69.740782    103.694000  4123.339844
#
# [1651 rows x 22 columns]

# %%
df_coin.set_index('Date',inplace= True)

# %%
fig2 = go.Figure()

fig2.add_trace(go.Scatter(x=df_coin.index, y=df_coin['Close'], name='Actual Values', mode='lines',line=dict(color='black')))
fig2.add_trace(go.Scatter(x=df_pred.index, y=df_pred['Close'], name='Predictions', mode='lines',line=dict(color='red')))
fig2.show()

# %%
df_coin.reset_index(inplace = True)

# %%
rf_final = RandomForestRegressor(random_state=10,criterion='mae',
 max_depth=20, max_features='auto', n_estimators=30)
yhyh = forecasting(rf_final,df_coin,5)

# %%
df_to_teste = df_coin[['Date','Close']]

# %%
df_to_teste.shape[0]
# Out:
# 1650

# %%
df_pred = pd.DataFrame(columns=['Date','Close'])

# %%
df_pred
# Out:
#         Date         Close
# 0 2022-05-17  29129.211589
# 1 2022-05-18  29294.203971
# 2 2022-05-19  29888.440169
# 3 2022-05-20  31202.188281
# 4 2022-05-21  30156.346875

# %%
for day, x in enumerate(yhyh):
    new_row={'Date':df_to_teste['Date'].max() + timedelta(days=1+day),
     'Close':x[0]}
    df_pred = df_pred.append(new_row, ignore_index=True)

# %%
df_pred['Date'] = pd.to_datetime(df_pred['Date'], format='%Y-%m-%d')
df_pred.set_index('Date',inplace=True)

# %%
df_pred.set_index('Date', inplace=True)

# %%
df_pred.T.reset_index()
# Out:
#        index             0
# 0 2022-05-17  29129.211589
# 1 2022-05-18  29294.203971
# 2 2022-05-19  29888.440169
# 3 2022-05-20  31202.188281
# 4 2022-05-21  30156.346875

# %%
df_pred = df_pred.T.reset_index()
df_pred
# Out:
#        index             0
# 0 2022-05-17  29129.211589
# 1 2022-05-18  29294.203971
# 2 2022-05-19  29888.440169
# 3 2022-05-20  31202.188281
# 4 2022-05-21  30156.346875

# %%
df_pred.rename({'index': 'Date',0:'Close'}, inplace=True)

# %%
def predictions(df_coin,model, forecast_lenght = 5, train_lenght = 100,target = 'Close'):
    """ df_coin must be with date in index,
        forecast_lenght is the amount of days that we will predict
        model is the model predefined to use to get our predictions
        train_length is the amount of days that we will use to train the model
        target is what we are predicting
        This will return a graphic that will contain the data from the train set and our predictions
    """
    df_coin = df_coin.tail(train_lenght)
    df_coin.reset_index(inplace=True)
    df_coin['Date'] = pd.to_datetime(df_coin['Date'], format='%Y-%m-%d')

    fig2 = go.Figure()
    fig2.add_trace(go.Scatter(x=df_coin['Date'], y=df_coin[target], 
                    name='Actual Values', mode='lines',line=dict(color='black')))
    #Predictions
    forecast = forecasting(model,df_coin,forecast_lenght)
    #df that will contain the predictions
    df_pred = pd.DataFrame(columns=['Date',target])
    #Adding the predictions to our dataset
    for day, x in enumerate(forecast):
        new_row={'Date':df_coin['Date'].max() + timedelta(days=1+day),
     target:x[0]}
        df_pred = df_pred.append(new_row, ignore_index=True)

    df_pred['Date'] = pd.to_datetime(df_pred['Date'], format='%Y-%m-%d')

    fig2.add_trace(go.Scatter(x=df_pred['Date'], y=df_pred[target], name='Predictions', mode='lines',line=dict(color='red')))
    fig2.update_layout(dict(updatemenus=[
                        dict(
                        type = "buttons",
                        direction = "left",
                        buttons=list([
                                dict(
                                args=["visible", "legendonly"],
                                label="Deselect All",
                                method="restyle"
                                ),
                                dict(
                                args=["visible", True],
                                label="Select All",
                                method="restyle"
                                )
                        ]),
                        pad={"r": 10, "t": 10},
                        showactive=False,
                        x=1,
                        xanchor="right",
                        y=1.1,
                        yanchor="top"
                        ),
                ]
        ))
    fig2.show()

# %%
df_coin.reset_index(inplace=True)

# %%
df_coin.drop(['level_0','index'],axis=1,inplace=True)

# %%
df_coin.drop('index', axis= 1, inplace=True)

# %%
df_coin.set_index('Date', inplace=True)

# %%
df_coin
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-11-09   7446.830078   7446.830078   7101.520020   7143.580078
# 2017-11-10   7173.729980   7312.000000   6436.870117   6618.140137
# 2017-11-11   6618.609863   6873.149902   6204.220215   6357.600098
# 2017-11-12   6295.450195   6625.049805   5519.009766   5950.069824
# 2017-11-13   5938.250000   6811.189941   5844.290039   6559.490234
# ...                  ...           ...           ...           ...
# 2022-05-13  29030.910156  30924.802734  28782.330078  29283.103516
# 2022-05-14  29285.642578  30192.802734  28702.910156  30101.265625
# 2022-05-15  30098.585938  31308.191406  29527.740234  31305.113281
# 2022-05-16  31304.375000  31305.341797  29251.884766  29862.917969
# 2022-05-17  29862.408203  30694.490234  29570.302734  30425.857422
#
#                Adj Close       Volume         SMA30         CMA30  \
# Date
# 2017-11-09   7143.580078   3226249984   6720.195964   1012.489040
# 2017-11-10   6618.140137   5208249856   6767.749967   1017.359285
# 2017-11-11   6357.600098   4908680192   6806.196647   1021.994910
# 2017-11-12   5950.069824   8957349888   6819.328646   1026.269043
# 2017-11-13   6559.490234   6263249920   6846.371322   1031.063862
# ...                  ...          ...           ...           ...
# 2022-05-13  29283.103516  42841124537  34769.086458  12181.561138
# 2022-05-14  30101.265625  28579868620  34201.849219  12187.967897
# 2022-05-15  31305.113281  25835372065  33774.531771  12194.800329
# 2022-05-16  29862.917969  32613897286  33200.786719  12201.112625
# 2022-05-17  30425.857422  29101473475  32660.555339  12207.621463
#
#                    EMA30        adx  ...       bb_high         macd  \
# Date                                 ...
# 2017-11-09   6798.973215  37.428679  ...   7929.899976   547.298468
# 2017-11-10   6776.369081  36.238180  ...   7899.045668   482.149729
# 2017-11-11   6724.022958  34.548539  ...   7835.311479   404.828866
# 2017-11-12   6627.278816  32.896648  ...   7798.154128   307.126870
# 2017-11-13   6618.805243  30.978407  ...   7771.077715   275.694434
# ...                  ...        ...  ...           ...          ...
# 2022-05-13  33752.713117  37.727339  ...  42450.221952 -2960.551674
# 2022-05-14  33296.282181  39.149053  ...  41921.267552 -2966.248122
# 2022-05-15  33047.386068  39.613857  ...  41377.532033 -2840.874322
# 2022-05-16  32649.327556  40.123429  ...  40596.192649 -2825.319270
# 2022-05-17  32371.393789  40.599029  ...  39589.225018 -2736.028041
#
#              macdsignal    macdhist        rsi        stdev      slowk  \
# Date
# 2017-11-09   521.809901   25.488567  65.836431   604.852006  33.184032
# 2017-11-10   513.877867  -31.728137  55.203600   565.647850  30.022892
# 2017-11-11   492.068066  -87.239201  50.841315   514.557416  13.668599
# 2017-11-12   455.079827 -147.952957  44.895661   489.412741  14.127749
# 2017-11-13   419.202748 -143.508315  53.591318   462.353197  27.607649
# ...                 ...         ...        ...          ...        ...
# 2022-05-13 -2152.011629 -808.540044  26.956772  3840.567747  25.449680
# 2022-05-14 -2314.858928 -651.389194  30.683438  3859.709167  42.259552
# 2022-05-15 -2420.062007 -420.812316  35.843737  3801.500131  61.600258
# 2022-05-16 -2501.113459 -324.205811  32.717422  3697.702965  72.797664
# 2022-05-17 -2548.096376 -187.931666  35.085322  3464.334839  74.824425
#
#                 slowd  dollar_close  sp500_close
# Date
# 2017-11-09  38.772059     94.351997  2584.620117
# 2017-11-10  33.577955     94.278000  2582.300049
# 2017-11-11  25.625174     94.278000  2582.300049
# 2017-11-12  19.273080     94.278000  2582.300049
# 2017-11-13  18.467999     94.388000  2584.840088
# ...               ...           ...          ...
# 2022-05-13  17.482894    103.694000  4123.339844
# 2022-05-14  28.706821    103.694000  4123.339844
# 2022-05-15  43.103163    103.694000  4123.339844
# 2022-05-16  58.885824    103.694000  4123.339844
# 2022-05-17  69.740782    103.694000  4123.339844
#
# [1651 rows x 22 columns]

# %%
predictions(df_coin,rf_final,5,100,'High')
